# %%
from openai import OpenAI

# Connect to LM Studio local server
client = OpenAI(
    base_url="http://localhost:1234/v1",
    api_key="lm-studio"  # any string works
)

# %%
# Send a simple prompt
response = client.chat.completions.create(
    model="qwen/qwen3-4b-2507",  # name can be anything in LM Studio
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Explain what a microcontroller is."}
    ],
    temperature=0.7
)

# Print response
print(response.choices[0].message.content)
# Out:
# A **microcontroller** is a compact integrated circuit designed to govern a specific operation in an embedded system. It contains a processor (central processing unit), memory (both RAM and ROM), and input/output (I/O) peripherals—all on a single chip.
#
# ### Key Components of a Microcontroller:
# 1. **Central Processing Unit (CPU)**: Executes instructions and performs calculations.
# 2. **Memory**:
#    - **Flash Memory or ROM**: Stores program code (non-volatile, retains data when power is off).
#    - **RAM**: Temporary storage for data and variables during operation.
# 3. **Input/Output (I/O) Ports**: Allow the microcontroller to interact with external devices (e.g., sensors, motors, buttons).
# 4. **Peripherals**: Built-in hardware modules such as timers, analog-to-digital converters (ADC), pulse-width modulation (PWM) controllers, serial communication interfaces (e.g., UART, SPI, I²C), and more.
#
# ### How It Works:
# A microcontroller runs a program (often stored in flash memory) that controls the behavior of a device. For example:
# - A smart thermostat uses a microcontroller to read temperature, adjust heating, and communicate with a Wi-Fi module.
# - A washing machine uses one to monitor water level, control motor speed, and manage the wash cycle.
#
# ### Advantages:
# - Cost-effective and energy-efficient.
# - Small size and low power consumption.
# - Ideal for simple, dedicated tasks in devices like appliances, vehicles, robotics, and consumer electronics.
#
# ### Example:
# The Arduino Uno is a popular microcontroller board used by hobbyists and professionals to build interactive electronic projects.
#
# In summary, a microcontroller is a self-contained computer-on-a-chip that makes devices intelligent and responsive by processing inputs and controlling outputs.

# %%
import keyboard
from langchain_community.chat_message_histories import ChatMessageHistory

# Initialize the history object to keep track of the discussion
history = ChatMessageHistory()

# %%
while True:
    query = input("\nUser (Type 'exit' or press ESC to end program): ")

    # Check for the ESC character (\x1b) OR a simple 'exit' command
    if keyboard.is_pressed('Esc') or query.lower() == 'exit':
        print("\nExiting...")
        print("Program Finished.")
        break
    
    if not query.strip():
        continue
    # Add user message to LangChain history
    history.add_user_message(query)

    # Convert LangChain 'human/ai' roles to OpenAI 'user/assistant' roles
    messages_with_history = []
    for m in history.messages:
        # LangChain uses 'human' for user and 'ai' for assistant
        role = "user" if m.type == "human" else "assistant"
        messages_with_history.append({"role": role, "content": m.content})

    # Ensured stream is called only once with the correctly mapped history
    stream = client.chat.completions.create(
        model="qwen/qwen3-4b-2507",
        messages=messages_with_history,
        stream=True
    )
    full_ai_response = ""       # Temporary variable to capture the full AI response for memory

    for chunk in stream:
        if chunk.choices[0].delta.content:
            content = chunk.choices[0].delta.content
            print(content, end="", flush=True)
            full_ai_response += content     # Build the string as it streams

    # Save the AI response back to LangChain history
    history.add_ai_message(full_ai_response)
    print()     # Print a newline for readability
    print('-' * 100)
# Out:
# Hi! 😊 How can I help you today?
# ----------------------------------------------------------------------------------------------------
# Yes, I remember you! 🌟 You're Guian Manalo, and we've had a few conversations already. How can I assist you today? 😊
# ----------------------------------------------------------------------------------------------------
# Yes! Here’s a quick reminder of what you asked earlier:
#
# Three known microcontrollers:
# - **Arduino Uno** – A popular, beginner-friendly microcontroller based on the ATmega328P.
# - **STM32F407** – A high-performance ARM Cortex-M4 microcontroller used in advanced embedded applications.
# - **ESP32** – A dual-core, Wi-Fi and Bluetooth-enabled microcontroller ideal for IoT devices.
#
# Let me know if you'd like more details or examples! 😊
# ----------------------------------------------------------------------------------------------------
# Your name is **Guian Manalo**! 😊 Nice to confirm — it's a great name. Is there anything specific you'd like to explore about microcontrollers or anything else? 😊
# ----------------------------------------------------------------------------------------------------
#
# Exiting...
# Program Finished.
