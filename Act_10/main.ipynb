# %%
from openai import OpenAI

# Connect to LM Studio local server
client = OpenAI(
    base_url="http://localhost:1234/v1",
    api_key="lm-studio"  # any string works
)

# %%
import keyboard
from langchain_community.chat_message_histories import ChatMessageHistory

# Initialize the history object to keep track of the discussion
history = ChatMessageHistory()

# %%
while True:
    query = input("\nUser (Enter to Continue || Type 'exit' or press ESC to exit): ")

    # Check for the ESC character (\x1b) OR a simple 'exit' command
    if keyboard.is_pressed('Esc') or query.lower() == 'exit':
        print("\nExiting...")
        print("Program Finished.")
        break
    print("User Input: " + query)
    print('- ' * 50)
    if not query.strip():
        continue
    # Add user message to LangChain history
    history.add_user_message(query)

    # Convert LangChain 'human/ai' roles to OpenAI 'user/assistant' roles
    messages_with_history = []
    for m in history.messages:
        # LangChain uses 'human' for user and 'ai' for assistant
        role = "user" if m.type == "human" else "assistant"
        messages_with_history.append({"role": role, "content": m.content})

    # Ensured stream is called only once with the correctly mapped history
    stream = client.chat.completions.create(
        model="qwen/qwen3-4b-2507",
        messages=messages_with_history,
        stream=True
    )
    full_ai_response = ""       # Temporary variable to capture the full AI response for memory

    for chunk in stream:
        if chunk.choices[0].delta.content:
            content = chunk.choices[0].delta.content
            print(content, end="", flush=True)
            full_ai_response += content     # Build the string as it streams

    # Save the AI response back to LangChain history
    history.add_ai_message(full_ai_response)
    print('\n ')     # Print a newline for readability
    print('=' * 100)
    print(' ')
# Out:
# User Input: Hi, I'm Guian Manalo
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Hi Guian Manalo! 🌟 It's a pleasure to meet you! 😊 How can I assist you today? Whether it's a question, a topic you'd like to explore, or just someone to chat with — I'm here for you! 💬✨ 😊
#
# ====================================================================================================
#
# User Input: Can you give me a 2 commonly used microcontroller, with one short description each
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Of course! Here are two commonly used microcontrollers with short descriptions:
#
# 1. **Arduino Uno**
# A popular, beginner-friendly microcontroller based on the ATmega328P chip. It features easy-to-use programming via the Arduino IDE and is widely used in hobby projects, education, and prototyping due to its simplicity and large community support.
#
# 2. **STM32 (e.g., STM32F407)**
# A family of powerful 32-bit microcontrollers from STMicroelectronics. Known for high performance, low power consumption, and rich peripheral features, STM32 chips are commonly used in industrial automation, robotics, and IoT applications.
#
# Let me know if you'd like to dive deeper into either one! 😊💡
#
# ====================================================================================================
#
# User Input: What is my name?
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Your name is **Guian Manalo** — you mentioned it earlier! 😊 It's a wonderful name, and I'm glad to have the chance to chat with you. How can I assist you today? 💬✨
#
# ====================================================================================================
#
#
# Exiting...
# Program Finished.
